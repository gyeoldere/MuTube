# %%
# !python3 generator_장르-및-특정-단어-제거.py --load_path='./checkpoint/1122cp/KoGPT2_checkpoint_480000.tar' --tmp_sent='휴식' --loops=20
# Out:
# /home/minji/.local/lib/python3.6/site-packages/mxnet/optimizer/optimizer.py:167: UserWarning: WARNING: New optimizer gluonnlp.optimizer.lamb.LAMB is overriding existing optimizer mxnet.optimizer.optimizer.LAMB
#   Optimizer.opt_registry[name].__name__))
# 2020-11-23 21:19:51.965877: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# To use data.metrics please install scikit-learn. See https://scikit-learn.org/stable/index.html
# 2020-11-23 21:19:53.695802: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-11-23 21:19:53.807767: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# ...

# %%
# !python3 generator_장르-및-특정-단어-제거.py --load_path='./checkpoint/1122cp/KoGPT2_checkpoint_480000.tar' --tmp_sent='신나는' --loops=20
# Out:
# /home/minji/.local/lib/python3.6/site-packages/mxnet/optimizer/optimizer.py:167: UserWarning: WARNING: New optimizer gluonnlp.optimizer.lamb.LAMB is overriding existing optimizer mxnet.optimizer.optimizer.LAMB
#   Optimizer.opt_registry[name].__name__))
# 2020-11-23 21:20:30.241281: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# To use data.metrics please install scikit-learn. See https://scikit-learn.org/stable/index.html
# 2020-11-23 21:20:31.966620: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-11-23 21:20:32.085371: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# ...

# %%
# !python3 generator_장르-및-특정-단어-제거.py --load_path='./checkpoint/1122cp/KoGPT2_checkpoint_480000.tar' --tmp_sent='댄스' --loops=20
# Out:
# /home/minji/.local/lib/python3.6/site-packages/mxnet/optimizer/optimizer.py:167: UserWarning: WARNING: New optimizer gluonnlp.optimizer.lamb.LAMB is overriding existing optimizer mxnet.optimizer.optimizer.LAMB
#   Optimizer.opt_registry[name].__name__))
# 2020-11-23 21:41:25.422626: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# To use data.metrics please install scikit-learn. See https://scikit-learn.org/stable/index.html
# 2020-11-23 21:41:27.202263: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-11-23 21:41:27.319920: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# ...

# %%
# !python3 generator_장르-및-특정-단어-제거.py --load_path='./checkpoint/1122cp/KoGPT2_checkpoint_480000.tar' --tmp_sent='힙합' --loops=20
# Out:
# /home/minji/.local/lib/python3.6/site-packages/mxnet/optimizer/optimizer.py:167: UserWarning: WARNING: New optimizer gluonnlp.optimizer.lamb.LAMB is overriding existing optimizer mxnet.optimizer.optimizer.LAMB
#   Optimizer.opt_registry[name].__name__))
# 2020-11-23 21:25:07.607159: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# To use data.metrics please install scikit-learn. See https://scikit-learn.org/stable/index.html
# 2020-11-23 21:25:09.318463: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-11-23 21:25:09.438057: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# ...

# %%
# !python3 generator_장르-및-특정-단어-제거.py --load_path='./checkpoint/1122cp/KoGPT2_checkpoint_480000.tar' --tmp_sent='메탈' --loops=30
# Out:
# /home/minji/.local/lib/python3.6/site-packages/mxnet/optimizer/optimizer.py:167: UserWarning: WARNING: New optimizer gluonnlp.optimizer.lamb.LAMB is overriding existing optimizer mxnet.optimizer.optimizer.LAMB
#   Optimizer.opt_registry[name].__name__))
# 2020-11-23 21:58:23.381861: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# To use data.metrics please install scikit-learn. See https://scikit-learn.org/stable/index.html
# 2020-11-23 21:58:25.104607: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-11-23 21:58:25.209167: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# ...

# %%
# !python3 generator_장르-및-특정-단어-제거.py --load_path='./checkpoint/1122cp/KoGPT2_checkpoint_480000.tar' --tmp_sent='이국적인' --loops=20
# Out:
# /home/minji/.local/lib/python3.6/site-packages/mxnet/optimizer/optimizer.py:167: UserWarning: WARNING: New optimizer gluonnlp.optimizer.lamb.LAMB is overriding existing optimizer mxnet.optimizer.optimizer.LAMB
#   Optimizer.opt_registry[name].__name__))
# 2020-11-23 21:28:57.800798: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# To use data.metrics please install scikit-learn. See https://scikit-learn.org/stable/index.html
# 2020-11-23 21:28:59.590029: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-11-23 21:28:59.713040: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# ...

# %%
# !python3 generator_장르-및-특정-단어-제거.py --load_path='./checkpoint/1122cp/KoGPT2_checkpoint_480000.tar' --tmp_sent='드라마틱' --loops=20
# Out:
# /home/minji/.local/lib/python3.6/site-packages/mxnet/optimizer/optimizer.py:167: UserWarning: WARNING: New optimizer gluonnlp.optimizer.lamb.LAMB is overriding existing optimizer mxnet.optimizer.optimizer.LAMB
#   Optimizer.opt_registry[name].__name__))
# 2020-11-23 21:30:29.437417: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# To use data.metrics please install scikit-learn. See https://scikit-learn.org/stable/index.html
# 2020-11-23 21:30:31.219350: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-11-23 21:30:31.337497: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# ...

# %%
# !python3 generator_장르-및-특정-단어-제거.py --load_path='./checkpoint/1122cp/KoGPT2_checkpoint_480000.tar' --tmp_sent='90년대' --loops=20
# Out:
# /home/minji/.local/lib/python3.6/site-packages/mxnet/optimizer/optimizer.py:167: UserWarning: WARNING: New optimizer gluonnlp.optimizer.lamb.LAMB is overriding existing optimizer mxnet.optimizer.optimizer.LAMB
#   Optimizer.opt_registry[name].__name__))
# 2020-11-23 21:27:00.280613: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# To use data.metrics please install scikit-learn. See https://scikit-learn.org/stable/index.html
# 2020-11-23 21:27:02.050842: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-11-23 21:27:02.179162: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# ...
